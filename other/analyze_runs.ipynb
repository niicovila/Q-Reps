# %%
import pandas as pd

# %%
lunal_lander = pd.read_csv('/Users/nicolasvila/workplace/uni/tfg_v2/CartPole_qreps_v3_optuna.csv')
# lunal_lander['reward'] = lunal_lander['reward'].apply(lambda x: float(x[1:-1]))
# lunal_lander = lunal_lander[lunal_lander['reward'] != 1111.0]

top_10_rewards_ll = lunal_lander.nlargest(22, 'reward')
top_10_rewards_ll.drop(['timestamp', 
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'experiment_tag',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        ], axis=1, inplace=True)

top_10_rewards_ll.reset_index(drop=True, inplace=True)

# %%
top_10_rewards_ll.head(22)
# Out:
#        reward  config/total_timesteps  config/num_steps  config/num_updates
# 0   94.250000                  100000               512                  50  \
# 1   81.625000                  100000               512                  50
# 2   62.750000                  100000               128                  50
# 3   56.875000                  100000               128                  50
# 4   54.333332                  100000               128                  50
# 5   50.714287                  100000               128                  50
# 6   47.250000                  100000               128                  50
# 7   43.250000                  100000               512                  50
# 8   42.375000                  100000               128                  50
# 9   41.625000                  100000               512                  50
# 10  41.375000                  100000               128                  50
# 11  41.375000                  100000               512                  50
# 12  41.250000                  100000               512                  50
# 13  40.500000                  100000               512                  50
# 14  39.375000                  100000               128                  50
# 15  39.250000                  100000               512                  50
# 16  37.500000                  100000               512                  50
# 17  37.000000                  100000               128                  50
# 18  36.500000                  100000               512                  50
# 19  36.375000                  100000               128                  50
# 20  35.500000                  100000               512                  50
# 21  35.375000                  100000               128                  50
#
#     config/buffer_size  config/update_epochs  config/update_policy_epochs
# 0                10000                    50                           50  \
# 1                10000                    50                           50
# 2                10000                    15                          150
# 3                10000                   150                          150
# 4                10000                    15                          150
# 5                10000                   150                          150
# 6                10000                   150                          150
# 7                10000                    15                          150
# 8                10000                    15                          150
# 9                10000                    15                          150
# 10               10000                    15                          150
# 11               10000                    15                          300
# 12               10000                    15                          300
# 13               10000                    15                          150
# 14               10000                    15                          300
# 15               10000                    15                          150
# 16               10000                    15                          150
# 17               10000                    15                          150
# 18               10000                    15                          150
# 19               10000                    15                          150
# 20               10000                    15                          150
# 21               10000                    15                          150
#
#     config/num_rollouts  config/num_envs  config/gamma  ...  config/beta
# 0                     8                1          0.99  ...     0.000250  \
# 1                     8                1          0.99  ...     0.000250
# 2                     8                1          0.99  ...     0.002000
# 3                     8                1          0.99  ...     0.002000
# 4                     8                1          0.99  ...     0.000250
# 5                     8                1          0.99  ...     0.002000
# 6                     8                1          0.99  ...     0.002000
# 7                     8                1          0.99  ...     0.000250
# 8                     8                1          0.99  ...     0.000250
# 9                     8                1          0.99  ...     0.000250
# 10                    8                1          0.99  ...     0.000250
# 11                    8                1          0.99  ...     0.000005
# 12                    8                1          0.99  ...     0.000250
# 13                    4                1          0.99  ...     0.000250
# 14                    8                1          0.99  ...     0.002000
# 15                    8                1          0.99  ...     0.000250
# 16                    8                1          0.99  ...     0.000250
# 17                    8                1          0.99  ...     0.002000
# 18                    8                1          0.99  ...     0.000250
# 19                    8                1          0.99  ...     0.002000
# 20                    8                1          0.99  ...     0.000250
# 21                    8                1          0.99  ...     0.002000
#
#     config/use_linear_schedule  config/saddle_point_optimization
# 0                        False                              True  \
# 1                        False                              True
# 2                        False                              True
# 3                        False                              True
# 4                        False                              True
# 5                        False                              True
# 6                        False                              True
# 7                        False                              True
# 8                        False                              True
# 9                        False                              True
# 10                       False                              True
# 11                       False                              True
# 12                       False                              True
# 13                       False                              True
# 14                       False                              True
# 15                       False                              True
# 16                        True                              True
# 17                       False                              True
# 18                       False                              True
# 19                       False                              True
# 20                       False                              True
# 21                       False                              True
#
#     config/use_kl_loss  config/policy_activation  config/num_hidden_layers
# 0                 True                      Tanh                         3  \
# 1                 True                      Tanh                         3
# 2                 True                      Tanh                         1
# 3                 True                      Tanh                         2
# 4                 True                      Tanh                         3
# 5                 True                      Tanh                         2
# 6                 True                      Tanh                         2
# 7                 True                      Tanh                         3
# 8                 True                      Tanh                         3
# 9                 True                      Tanh                         3
# 10                True                      Tanh                         3
# 11                True                      Tanh                         3
# 12                True                      Tanh                         3
# 13                True                      Tanh                         3
# 14                True                      Tanh                         3
# 15                True                      Tanh                         3
# 16                True                      Tanh                         3
# 17                True                      Tanh                         3
# 18                True                      Tanh                         3
# 19                True                      Tanh                         3
# 20                True                      Tanh                         3
# 21                True                      Tanh                         1
#
#     config/hidden_size  config/q_activation  config/q_hidden_size
# 0                  256                 Tanh                   256  \
# 1                  256                 Tanh                   256
# 2                  256                 ReLU                   256
# 3                  256                 Tanh                   256
# 4                  128                 Tanh                   128
# 5                  256                 Tanh                   256
# 6                  256                 Tanh                   256
# 7                  128                 Tanh                   256
# 8                  256                 Tanh                   256
# 9                  128                 Tanh                   256
# 10                 128                 ReLU                   256
# 11                 128                 Tanh                   256
# 12                 128                 Tanh                   128
# 13                 128                 Tanh                    64
# 14                 128                 ReLU                   256
# 15                 128                 Tanh                   256
# 16                 128                 ReLU                   256
# 17                 128                 ReLU                   256
# 18                 128                 Tanh                   256
# 19                 128                 ReLU                   256
# 20                 128                 Tanh                   256
# 21                 256                 ReLU                   256
#
#     config/q_num_hidden_layers
# 0                            4
# 1                            4
# 2                            2
# 3                            8
# 4                            8
# 5                            8
# 6                            8
# 7                            8
# 8                            4
# 9                            8
# 10                           8
# 11                           8
# 12                           8
# 13                           8
# 14                           4
# 15                           8
# 16                           4
# 17                           8
# 18                           8
# 19                           8
# 20                           8
# 21                           2
#
# [22 rows x 26 columns]

# %%
top_10_rewards_ll.to_csv('top_runs_CartPole.csv', index=False)

# %%
import pandas as pd

# Assuming you have two dataframes: top_10_rewards_cp and top_10_rewards_ll

# Function to find similar configurations
def find_similar_configurations(df1, df2):
    similar_configurations = []

    for idx1, row1 in df1.iterrows():
        for idx2, row2 in df2.iterrows():
            similarity_score = sum(row1[:-1] == row2[:-1])
            if similarity_score > 0:
                similar_configurations.append((idx1, idx2, similarity_score))

    return similar_configurations

# Find similar configurations
similar_configurations = find_similar_configurations(top_10_rewards_cp, top_10_rewards_ll)
similar_configurations.sort(key=lambda x: x[2], reverse=True)
# Print the top similar configurations
for config in similar_configurations[:10]:
    idx1, idx2, similarity_score = config
    print("Similarity Score:", similarity_score)
    print("Configuration CP (Index {}):".format(idx1))
    print(top_10_rewards_cp.iloc[idx1])
    print("Configuration LL (Index {}):".format(idx2))
    print(top_10_rewards_ll.iloc[idx2])
    print("="*50)
# Out:
# Similarity Score: 10
# Configuration CP (Index 3):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 3, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 10
# Configuration CP (Index 9):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                           0.002
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 9, dtype: object
# Configuration LL (Index 2):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                              0.002
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 2, dtype: object
# ==================================================
# Similarity Score: 10
# Configuration CP (Index 11):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                            0.01
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 11, dtype: object
# Configuration LL (Index 1):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                               0.01
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 1, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 0):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                      0.0002
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 0, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 0):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                      0.0002
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 0, dtype: object
# Configuration LL (Index 5):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                         0.0002
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 5, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 1):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                     0.00001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 1, dtype: object
# Configuration LL (Index 6):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                   0.00001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 6, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 2):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 2, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 2):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 2, dtype: object
# Configuration LL (Index 11):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                          0.001
# config/policy_lr_end                   0.00001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 11, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 6):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 6, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 9):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                           0.002
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 9, dtype: object
# Configuration LL (Index 1):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                               0.01
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 1, dtype: object
# ==================================================
