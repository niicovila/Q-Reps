# %%
import pandas as pd

# %% [markdown]
# ## Analyze hyperparameter tune runs

# %%
runs = pd.read_csv('/Users/nicolasvila/workplace/uni/tfg_v2/tests/CartPole_qreps_v2_tune_no_anneal.csv')
top_runs = runs.nlargest(22, 'reward')
top_runs.drop(['timestamp', 
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'experiment_tag',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/batch_size',
                        'config/num_iterations',
                        'config/num_steps',
                        'config/tau'
                        ], axis=1, inplace=True)

top_runs.reset_index(drop=True, inplace=True)
top_runs.head(22)

# %% [markdown]
# ## Compute reward average accross seeds

# %%
averages = runs.groupby(runs.index // 3).agg({'reward': 'mean', **{col: 'first' for col in runs.columns if col != 'reward'}}).reset_index(drop=True)
averages = averages.sort_values(by='reward', ascending=False)
averages.reset_index(drop=True, inplace=True)
averages.drop(['config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/batch_size',
                        'config/num_iterations',
                        'config/eta',
                        'config/tau',
                        'config/minibatch_size',
                        'config/parametrized_sampler',
                        'config/saddle_point_optimization',
                        'config/target_network_frequency',
                        'config/use_kl_loss',
                        'config/target_network'
                        ], axis=1, inplace=True)

averages.reset_index(drop=True, inplace=True)
averages.head()
# result_df.to_csv('CartPole_qreps_v2-1-averaging.csv', index=False)
# Out:
#        reward  config/num_envs  config/num_steps  config/num_minibatches
# 0  361.060605                4               256                       8  \
# 1  350.492753                4               256                       8
# 2  219.731183                4               256                       8
# 3  212.060984                4               500                      16
# 4  201.681249                4               256                      16
#
#    config/alpha  config/update_epochs  config/beta  config/policy_lr_start
# 0             8                   100     0.007081                0.002237  \
# 1             8                   100     0.007081                0.002237
# 2             4                   100     0.007081                0.002237
# 3             4                   100     0.001090                0.001372
# 4             8                   100     0.005424                0.002237
#
#    config/q_lr_start  config/use_kl_loss  config/anneal_lr
# 0           0.002356               False             False  \
# 1           0.002356               False             False
# 2           0.002356               False              True
# 3           0.002155               False             False
# 4           0.002834               False              True
#
#   config/policy_activation  config/num_hidden_layers  config/hidden_size
# 0                     ReLU                         4                 128  \
# 1                     ReLU                         4                 128
# 2                     ReLU                         4                 128
# 3                     ReLU                         4                 128
# 4                     ReLU                         4                 128
#
#   config/q_activation  config/q_hidden_size  config/q_num_hidden_layers
# 0                Tanh                   128                           4  \
# 1                Tanh                   128                           4
# 2             Sigmoid                    64                           4
# 3                Tanh                   128                           4
# 4                Tanh                    64                           4
#
#   config/q_optimizer config/actor_optimizer    config/eps
# 0                SGD                   Adam  1.000000e-08
# 1                SGD                   Adam  1.000000e-08
# 2                SGD                   Adam  1.000000e-08
# 3                SGD                   Adam  1.000000e-08
# 4                SGD                   Adam  1.000000e-08
