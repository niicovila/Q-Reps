# %%
import pandas as pd

# %% [markdown]
# ## Analyze hyperparameter tune runs

# %%
runs = pd.read_csv('/Users/nicolasvila/workplace/uni/tfg_v2/tests/tune_results_hebo_512_target.csv')
top_runs = runs.nlargest(22, 'reward')
top_runs.drop(['timestamp', 
                        'checkpoint_dir_name', 
                        'done',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/num_iterations',
                        'config/num_steps',
                        ], axis=1, inplace=True)

top_runs.reset_index(drop=True, inplace=True)
top_runs.head(22)
# Out:
#     Unnamed: 0  reward  training_iteration  trial_id  config/num_envs
# 0           15   500.0                   9  9b153f2c               16  \
# 1           30   500.0                  31  8226d762              128
# 2           33   500.0                   8  f8a119b5               32
# 3           35   500.0                  11  e9baa271               16
# 4           40   500.0                  18  d353c727              128
# 5           49   500.0                  11  ce997648               16
# 6           57   500.0                  38  5fc83651               16
# 7           80   500.0                   9  738f05ea               16
# 8           90   500.0                  14  eae1e7c5               32
# 9           92   500.0                  17  5b4d87af               16
# 10          94   500.0                  20  953ba17d               16
# 11         111   500.0                   9  bd7e7d25               16
# 12         117   500.0                  14  d65104b7               16
# 13         118   500.0                  11  61d712a0               16
# 14         119   500.0                   9  e1bfcc89               16
# 15         121   500.0                   9  fd67ed4f               32
# 16         122   500.0                  12  128a1e06               16
# 17         123   500.0                  13  ce6bab78               32
# 18         125   500.0                  12  7491a03d               16
# 19         135   500.0                  10  d6afb885               32
# 20         138   500.0                  14  52849ff4               16
# 21         141   500.0                   7  8132dceb               16
#
#     config/total_iterations  config/num_minibatches  config/update_epochs
# 0                      2048                      16                    50  \
# 1                      2048                      16                   150
# 2                      2048                      16                   150
# 3                      1024                       8                    50
# 4                      2048                       8                    50
# 5                      2048                      16                   150
# 6                      1024                       8                   100
# 7                      2048                      16                   150
# 8                      2048                       8                   150
# 9                      2048                       4                    50
# 10                     1024                       8                   100
# 11                     1024                      32                   100
# 12                     2048                      16                   100
# 13                     2048                      16                    50
# 14                     2048                       8                    50
# 15                     2048                       8                   100
# 16                     2048                      32                   100
# 17                     2048                      64                   150
# 18                     1024                      64                   100
# 19                     2048                       8                   150
# 20                     1024                      16                   150
# 21                     2048                      16                   150
#
#     config/update_epochs_policy  config/alpha  ...  config/actor_optimizer
# 0                            50             2  ...                    Adam  \
# 1                            50            12  ...                    Adam
# 2                            50             4  ...                    Adam
# 3                            50            12  ...                    Adam
# 4                            50            12  ...                    Adam
# 5                            50             2  ...                    Adam
# 6                            50             2  ...                    Adam
# 7                            50             4  ...                    Adam
# 8                            50             4  ...                    Adam
# 9                            50             4  ...                    Adam
# 10                           50             4  ...                    Adam
# 11                           50             4  ...                    Adam
# 12                           50             2  ...                    Adam
# 13                           50             4  ...                    Adam
# 14                           50             2  ...                    Adam
# 15                           50             4  ...                    Adam
# 16                           50             8  ...                    Adam
# 17                           50            32  ...                    Adam
# 18                           50             4  ...                    Adam
# 19                           50             4  ...                    Adam
# 20                           50             8  ...                    Adam
# 21                           50             4  ...                    Adam
#
#       config/eps  config/average_critics  config/normalize_delta
# 0   1.000000e-08                    True                   False  \
# 1   1.000000e-08                   False                   False
# 2   1.000000e-08                   False                   False
# 3   1.000000e-08                   False                   False
# 4   1.000000e-08                   False                   False
# 5   1.000000e-08                    True                   False
# 6   1.000000e-08                   False                   False
# 7   1.000000e-08                    True                   False
# 8   1.000000e-08                   False                   False
# 9   1.000000e-08                    True                   False
# 10  1.000000e-08                   False                   False
# 11  1.000000e-08                    True                   False
# 12  1.000000e-08                   False                   False
# 13  1.000000e-08                   False                   False
# 14  1.000000e-08                    True                   False
# 15  1.000000e-08                   False                   False
# 16  1.000000e-08                   False                   False
# 17  1.000000e-08                    True                   False
# 18  1.000000e-08                   False                   False
# 19  1.000000e-08                   False                   False
# 20  1.000000e-08                   False                   False
# 21  1.000000e-08                    True                   False
#
#    config/use_kl_loss config/target_network  config/gae_lambda
# 0                True                 False               0.95  \
# 1                True                 False               0.95
# 2               False                 False               0.95
# 3                True                 False               0.95
# 4                True                 False               0.95
# 5                True                 False               0.95
# 6                True                 False               0.95
# 7                True                 False               0.95
# 8                True                 False               0.95
# 9               False                 False               0.95
# 10               True                 False               0.95
# 11               True                 False               0.95
# 12              False                 False               0.95
# 13              False                 False               0.95
# 14              False                 False               0.95
# 15               True                 False               0.95
# 16               True                 False               0.95
# 17               True                 False               0.95
# 18               True                 False               0.95
# 19               True                 False               0.95
# 20               True                 False               0.95
# 21              False                 False               0.95
#
#     config/save_learning_curve  config/minibatch_size    logdir
# 0                        False                      0  9b153f2c
# 1                        False                      0  8226d762
# 2                        False                      0  f8a119b5
# 3                        False                      0  e9baa271
# 4                        False                      0  d353c727
# 5                        False                      0  ce997648
# 6                        False                      0  5fc83651
# 7                        False                      0  738f05ea
# 8                        False                      0  eae1e7c5
# 9                        False                      0  5b4d87af
# 10                       False                      0  953ba17d
# 11                       False                      0  bd7e7d25
# 12                       False                      0  d65104b7
# 13                       False                      0  61d712a0
# 14                       False                      0  e1bfcc89
# 15                       False                      0  fd67ed4f
# 16                       False                      0  128a1e06
# 17                       False                      0  ce6bab78
# 18                       False                      0  7491a03d
# 19                       False                      0  d6afb885
# 20                       False                      0  52849ff4
# 21                       False                      0  8132dceb
#
# [22 rows x 35 columns]

# %%
runs['training_iteration'].mean()
# Out:
# 15.634765625

# %% [markdown]
# ## Average episodic return accross seeds

# %%
averages = runs.groupby(runs.index // 4).agg({'reward': 'mean', **{col: 'first' for col in runs.columns if col != 'reward'}}).reset_index(drop=True)
averages = averages.sort_values(by='reward', ascending=False)
averages.reset_index(drop=True, inplace=True)
averages.drop(['config/total_timesteps',
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/num_iterations',
                        'config/num_steps',
                        'config/tau'
                        ], axis=1, inplace=True)

averages.reset_index(drop=True, inplace=True)
averages.head()
# result_df.to_csv('CartPole_qreps_v2-1-averaging.csv', index=False)
# Out:
#        reward  Unnamed: 0   timestamp  config/num_envs
# 0  139.576699         256  1714610198                4  \
# 1  137.400545         164  1714605194                4
# 2  129.447463          40  1714603345                4
# 3  127.435646         460  1714636086                4
# 4   95.865802         372  1714633187                4
#
#    config/total_iterations  config/num_minibatches  config/update_epochs
# 0                     2048                      16                    50  \
# 1                     2048                      16                    50
# 2                     2048                      16                    50
# 3                     2048                      16                    50
# 4                     2048                      16                    50
#
#    config/alpha  config/eta  config/beta  ...  config/sampler_optimizer
# 0            12         NaN      0.00300  ...                      Adam  \
# 1            12         NaN      0.00300  ...                      Adam
# 2             4         NaN      0.00300  ...                      Adam
# 3            12         NaN      0.00025  ...                      Adam
# 4            32         NaN      0.00030  ...                      Adam
#
#      config/eps  config/saddle_point_optimization config/average_critics
# 0  1.000000e-08                              True                   True  \
# 1  1.000000e-08                              True                   True
# 2  1.000000e-08                              True                   True
# 3  1.000000e-08                              True                   True
# 4  1.000000e-08                              True                   True
#
#   config/normalize_delta  config/use_kl_loss  config/target_network
# 0                  False               False                  False  \
# 1                  False               False                  False
# 2                  False               False                  False
# 3                  False               False                  False
# 4                  False               False                  False
#
#    config/target_network_frequency config/minibatch_size    logdir
# 0                                0                     0  05c07b5f
# 1                                0                     0  4642856b
# 2                                0                     0  01444919
# 3                                0                     0  e5f6f4bf
# 4                                0                     0  99782311
#
# [5 rows x 35 columns]
