# %%
import pandas as pd

# %%
lunar_lander = pd.read_csv('/Users/nicolasvila/workplace/uni/tfg_v2/tests/other/qreps_v2/CartPole_qreps_v2-1.csv')
# lunal_lander['reward'] = lunal_lander['reward'].apply(lambda x: float(x[1:-1]))
# lunal_lander = lunal_lander[lunal_lander['reward'] != 1111.0]

top_10_rewards_ll = lunar_lander.nlargest(22, 'reward')
top_10_rewards_ll.drop(['timestamp', 
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'experiment_tag',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/batch_size',
                        'config/num_iterations',
                        'config/actor_optimizer',
                        'config/minibatch_size',
                        'config/saddle_point_optimization',
                        'config/eta',
                        'config/num_envs',
                        'config/num_steps',
                        'config/tau'
                        ], axis=1, inplace=True)

top_10_rewards_ll.reset_index(drop=True, inplace=True)

# %%
filtered_df = lunar_lander[lunar_lander['config/target_network'] == True]
filtered_df.drop(['timestamp', 
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'experiment_tag',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/batch_size',
                        'config/num_iterations',
                        'config/actor_optimizer',
                        'config/minibatch_size',
                        'config/saddle_point_optimization',
                        'config/eta',
                        'config/num_envs',
                        'config/num_steps',
                        'config/tau'
                        ], axis=1, inplace=True)
filtered_df.head(50)
# Out:
# /var/folders/rz/cwn_bhpd7x9bm5nv218wrcx80000gn/T/ipykernel_43384/4128778625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(['timestamp',
#          reward  config/num_minibatches  config/alpha  config/update_epochs
# 0   -111.000000                       8             8                   100  \
# 1   -111.000000                       8             8                   100
# 6   -111.000000                       4            12                    10
# 7   -111.000000                       4            12                    10
# 10    18.372726                      16             4                    10
# 11    18.163637                      16             4                    10
# 12  -111.000000                       8             2                   100
# 13  -111.000000                       8             2                   100
# 16  -111.000000                       8             8                    50
# 17  -111.000000                       8             8                    50
# 22  -111.000000                      16             8                    50
# 23  -111.000000                      16             8                    50
# 26  -111.000000                       4             2                    50
# 27  -111.000000                       4             2                    50
# 28  -111.000000                       8             4                    50
# 29  -111.000000                       8             4                    50
# 32  -111.000000                       4             2                    50
# 33  -111.000000                       4             2                    50
# 38  -111.000000                       8             4                    50
# 39  -111.000000                       8             4                    50
# 42  -111.000000                       8             8                    50
# 43  -111.000000                       8             8                    50
# 44  -111.000000                      16             8                    50
# 45  -111.000000                      16             8                    50
# 164 -111.000000                      16             4                    10
# 165 -111.000000                      16             4                    10
#
#      config/target_network_frequency  config/beta  config/policy_lr_start
# 0                                 12     0.032874                0.000171  \
# 1                                 12     0.032874                0.000171
# 6                                  6     0.013877                0.010034
# 7                                  6     0.013877                0.010034
# 10                                 6     0.000340                0.006043
# 11                                 6     0.000340                0.006043
# 12                                12     0.000808                0.000355
# 13                                12     0.000808                0.000355
# 16                                 2     0.047069                0.001334
# 17                                 2     0.047069                0.001334
# 22                                 6     0.003532                0.034928
# 23                                 6     0.003532                0.034928
# 26                                 6     0.000235                0.047222
# 27                                 6     0.000235                0.047222
# 28                                 2     0.003139                0.001237
# 29                                 2     0.003139                0.001237
# 32                                 2     0.019147                0.000953
# 33                                 2     0.019147                0.000953
# 38                                 6     0.008068                0.056056
# 39                                 6     0.008068                0.056056
# 42                                 6     0.000467                0.033731
# 43                                 6     0.000467                0.033731
# 44                                 2     0.001107                0.001985
# 45                                 2     0.001107                0.001985
# 164                               12     0.065669                0.000239
# 165                               12     0.065669                0.000239
#
#      config/q_lr_start  config/use_kl_loss  config/target_network
# 0             0.000327                True                   True  \
# 1             0.000327                True                   True
# 6             0.089801                True                   True
# 7             0.089801                True                   True
# 10            0.000234                True                   True
# 11            0.000234                True                   True
# 12            0.022316                True                   True
# 13            0.022316                True                   True
# 16            0.027623               False                   True
# 17            0.027623               False                   True
# 22            0.000123               False                   True
# 23            0.000123               False                   True
# 26            0.047273               False                   True
# 27            0.047273               False                   True
# 28            0.000405               False                   True
# 29            0.000405               False                   True
# 32            0.000577                True                   True
# 33            0.000577                True                   True
# 38            0.005900                True                   True
# 39            0.005900                True                   True
# 42            0.002324                True                   True
# 43            0.002324                True                   True
# 44            0.008233                True                   True
# 45            0.008233                True                   True
# 164           0.015666               False                   True
# 165           0.015666               False                   True
#
#      config/anneal_lr  config/parametrized_sampler config/policy_activation
# 0                True                        False                     Tanh  \
# 1                True                        False                     Tanh
# 6                True                        False                     Tanh
# 7                True                        False                     Tanh
# 10               True                        False                     ReLU
# 11               True                        False                     ReLU
# 12               True                        False                     ReLU
# 13               True                        False                     ReLU
# 16              False                        False                     Tanh
# 17              False                        False                     Tanh
# 22              False                        False                     Tanh
# 23              False                        False                     Tanh
# 26              False                        False                     ReLU
# 27              False                        False                     ReLU
# 28              False                        False                     ReLU
# 29              False                        False                     ReLU
# 32               True                        False                     Tanh
# 33               True                        False                     Tanh
# 38               True                        False                     Tanh
# 39               True                        False                     Tanh
# 42               True                        False                     ReLU
# 43               True                        False                     ReLU
# 44               True                        False                     ReLU
# 45               True                        False                     ReLU
# 164             False                        False                     Tanh
# 165             False                        False                     Tanh
#
#      config/num_hidden_layers  config/hidden_size config/q_activation
# 0                           2                 512                Tanh  \
# 1                           2                 512                Tanh
# 6                           4                  64                Tanh
# 7                           4                  64                Tanh
# 10                          4                 512                ReLU
# 11                          4                 512                ReLU
# 12                          2                  64                ReLU
# 13                          2                  64                ReLU
# 16                          4                  64                ReLU
# 17                          4                  64                ReLU
# 22                          2                 512                ReLU
# 23                          2                 512                ReLU
# 26                          2                  64                Tanh
# 27                          2                  64                Tanh
# 28                          4                 512                Tanh
# 29                          4                 512                Tanh
# 32                          4                 128                Tanh
# 33                          4                 128                Tanh
# 38                          2                 128                Tanh
# 39                          2                 128                Tanh
# 42                          2                 128                ReLU
# 43                          2                 128                ReLU
# 44                          4                 128                ReLU
# 45                          4                 128                ReLU
# 164                         2                 128                ReLU
# 165                         2                 128                ReLU
#
#      config/q_hidden_size  config/q_num_hidden_layers config/q_optimizer
# 0                     512                           4                SGD  \
# 1                     512                           4                SGD
# 6                      64                           4                SGD
# 7                      64                           4                SGD
# 10                    128                           2                SGD
# 11                    128                           2                SGD
# 12                    128                           2                SGD
# 13                    128                           2                SGD
# 16                     64                           2                SGD
# 17                     64                           2                SGD
# 22                    512                           2                SGD
# 23                    512                           2                SGD
# 26                    128                           4                SGD
# 27                    128                           4                SGD
# 28                    128                           4                SGD
# 29                    128                           4                SGD
# 32                    512                           2                SGD
# 33                    512                           2                SGD
# 38                     64                           2                SGD
# 39                     64                           2                SGD
# 42                    128                           4                SGD
# 43                    128                           4                SGD
# 44                    128                           4                SGD
# 45                    128                           4                SGD
# 164                    64                           4                SGD
# 165                    64                           4                SGD
#
#        config/eps
# 0    1.000000e-08
# 1    1.000000e-08
# 6    1.000000e-04
# 7    1.000000e-04
# 10   1.000000e-08
# 11   1.000000e-08
# 12   1.000000e-04
# 13   1.000000e-04
# 16   1.000000e-04
# 17   1.000000e-04
# 22   1.000000e-08
# 23   1.000000e-08
# 26   1.000000e-04
# 27   1.000000e-04
# 28   1.000000e-08
# 29   1.000000e-08
# 32   1.000000e-04
# 33   1.000000e-04
# 38   1.000000e-08
# 39   1.000000e-08
# 42   1.000000e-04
# 43   1.000000e-04
# 44   1.000000e-08
# 45   1.000000e-08
# 164  1.000000e-08
# 165  1.000000e-08

# %%
top_10_rewards_ll.head(22)
# Out:
#         reward  config/num_minibatches  config/alpha  config/update_epochs
# 0   500.000000                      16             4                    50  \
# 1   333.750000                      16             4                   100
# 2   284.200012                      16             4                    50
# 3    95.166664                      16             4                    50
# 4    85.379311                       4             4                    50
# 5    67.925926                       4             4                   100
# 6    65.290321                       8             8                    10
# 7    58.000000                       4             4                   100
# 8    50.222221                      16             4                    50
# 9    49.974998                      16             4                    50
# 10   49.500000                       4             4                    50
# 11   48.452381                      16             4                    50
# 12   47.909092                       4             4                    50
# 13   45.755554                       8             4                    50
# 14   45.000000                       4            12                    50
# 15   44.391304                      16             4                    50
# 16   41.645832                       4             4                   100
# 17   41.333332                       4             8                    50
# 18   40.729168                       4             4                   100
# 19   40.340000                       4             4                   100
# 20   40.340000                      16             8                   100
# 21   39.096153                       8             2                    10
#
#     config/target_network_frequency  config/beta  config/policy_lr_start
# 0                                12     0.000100                0.002318  \
# 1                                 2     0.000112                0.007335
# 2                                 2     0.000101                0.003137
# 3                                 2     0.000341                0.000446
# 4                                 6     0.000169                0.001992
# 5                                 2     0.000533                0.001780
# 6                                 2     0.000136                0.001361
# 7                                 6     0.064735                0.015865
# 8                                 6     0.000510                0.001378
# 9                                12     0.000114                0.023651
# 10                               12     0.000100                0.002232
# 11                               12     0.000100                0.002318
# 12                                6     0.000131                0.001848
# 13                               12     0.000126                0.003088
# 14                               12     0.000136                0.011381
# 15                                2     0.000111                0.004162
# 16                                2     0.000452                0.002300
# 17                                2     0.006654                0.000602
# 18                                6     0.001093                0.002166
# 19                                2     0.000533                0.001780
# 20                               12     0.000101                0.003616
# 21                               12     0.004858                0.000108
#
#     config/q_lr_start  config/use_kl_loss  config/target_network
# 0            0.001492               False                  False  \
# 1            0.001157               False                  False
# 2            0.001399               False                  False
# 3            0.000457               False                  False
# 4            0.001450               False                  False
# 5            0.000874               False                  False
# 6            0.000446               False                  False
# 7            0.000543               False                  False
# 8            0.001139               False                  False
# 9            0.000136               False                  False
# 10           0.001481               False                  False
# 11           0.001492               False                  False
# 12           0.002305               False                  False
# 13           0.001569               False                  False
# 14           0.003413               False                  False
# 15           0.001372               False                  False
# 16           0.002817               False                  False
# 17           0.003364               False                  False
# 18           0.002354               False                  False
# 19           0.000874               False                  False
# 20           0.001393               False                  False
# 21           0.054249               False                  False
#
#     config/anneal_lr  config/parametrized_sampler config/policy_activation
# 0               True                        False                     Tanh  \
# 1              False                        False                     ReLU
# 2              False                        False                     ReLU
# 3              False                        False                     ReLU
# 4              False                        False                     Tanh
# 5              False                        False                     ReLU
# 6               True                        False                     Tanh
# 7              False                        False                     Tanh
# 8               True                        False                     Tanh
# 9               True                        False                     Tanh
# 10              True                        False                     ReLU
# 11              True                        False                     Tanh
# 12              True                        False                     ReLU
# 13              True                        False                     ReLU
# 14              True                        False                     Tanh
# 15             False                        False                     Tanh
# 16              True                        False                     Tanh
# 17             False                        False                     Tanh
# 18              True                        False                     Tanh
# 19             False                        False                     ReLU
# 20              True                        False                     Tanh
# 21             False                        False                     Tanh
#
#     config/num_hidden_layers  config/hidden_size config/q_activation
# 0                          4                 128                Tanh  \
# 1                          2                 128                Tanh
# 2                          2                 128                ReLU
# 3                          2                 128                ReLU
# 4                          4                 128                Tanh
# 5                          2                  64                ReLU
# 6                          2                 128                Tanh
# 7                          2                  64                Tanh
# 8                          2                  64                ReLU
# 9                          2                 128                ReLU
# 10                         4                 128                Tanh
# 11                         4                 128                Tanh
# 12                         4                 512                Tanh
# 13                         2                 128                ReLU
# 14                         4                 128                ReLU
# 15                         2                 128                Tanh
# 16                         4                 128                ReLU
# 17                         2                 128                Tanh
# 18                         4                 128                ReLU
# 19                         2                  64                ReLU
# 20                         2                 512                Tanh
# 21                         4                 512                Tanh
#
#     config/q_hidden_size  config/q_num_hidden_layers config/q_optimizer
# 0                     64                           2                SGD  \
# 1                     64                           2                SGD
# 2                    128                           2                SGD
# 3                    128                           2                SGD
# 4                    128                           2                SGD
# 5                     64                           2                SGD
# 6                     64                           2                SGD
# 7                    512                           2                SGD
# 8                    128                           2                SGD
# 9                     64                           2                SGD
# 10                    64                           4                SGD
# 11                    64                           2                SGD
# 12                    64                           4                SGD
# 13                    64                           4                SGD
# 14                   128                           4                SGD
# 15                   128                           2                SGD
# 16                   128                           4                SGD
# 17                    64                           4                SGD
# 18                    64                           4                SGD
# 19                    64                           2                SGD
# 20                   128                           2                SGD
# 21                    64                           2                SGD
#
#       config/eps
# 0   1.000000e-08
# 1   1.000000e-04
# 2   1.000000e-08
# 3   1.000000e-04
# 4   1.000000e-04
# 5   1.000000e-08
# 6   1.000000e-04
# 7   1.000000e-04
# 8   1.000000e-08
# 9   1.000000e-08
# 10  1.000000e-08
# 11  1.000000e-08
# 12  1.000000e-08
# 13  1.000000e-08
# 14  1.000000e-04
# 15  1.000000e-08
# 16  1.000000e-08
# 17  1.000000e-04
# 18  1.000000e-08
# 19  1.000000e-08
# 20  1.000000e-04
# 21  1.000000e-08

# %%
top_10_rewards_ll.to_csv('top_runs_CartPole.csv', index=False)

# %%
import pandas as pd

# Assuming you have two dataframes: top_10_rewards_cp and top_10_rewards_ll

# Function to find similar configurations
def find_similar_configurations(df1, df2):
    similar_configurations = []

    for idx1, row1 in df1.iterrows():
        for idx2, row2 in df2.iterrows():
            similarity_score = sum(row1[:-1] == row2[:-1])
            if similarity_score > 0:
                similar_configurations.append((idx1, idx2, similarity_score))

    return similar_configurations

# Find similar configurations
similar_configurations = find_similar_configurations(top_10_rewards_cp, top_10_rewards_ll)
similar_configurations.sort(key=lambda x: x[2], reverse=True)
# Print the top similar configurations
for config in similar_configurations[:10]:
    idx1, idx2, similarity_score = config
    print("Similarity Score:", similarity_score)
    print("Configuration CP (Index {}):".format(idx1))
    print(top_10_rewards_cp.iloc[idx1])
    print("Configuration LL (Index {}):".format(idx2))
    print(top_10_rewards_ll.iloc[idx2])
    print("="*50)
# Out:
# Similarity Score: 10
# Configuration CP (Index 3):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 3, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 10
# Configuration CP (Index 9):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                           0.002
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 9, dtype: object
# Configuration LL (Index 2):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                              0.002
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 2, dtype: object
# ==================================================
# Similarity Score: 10
# Configuration CP (Index 11):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                            0.01
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 11, dtype: object
# Configuration LL (Index 1):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                               0.01
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 1, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 0):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                      0.0002
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 0, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 0):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                      0.0002
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 0, dtype: object
# Configuration LL (Index 5):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                         0.0002
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 5, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 1):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                     0.00001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 1, dtype: object
# Configuration LL (Index 6):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                   0.00001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 6, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 2):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 2, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 2):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 2, dtype: object
# Configuration LL (Index 11):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                          0.001
# config/policy_lr_end                   0.00001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 11, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 6):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 6, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 9):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                           0.002
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 9, dtype: object
# Configuration LL (Index 1):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                               0.01
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 1, dtype: object
# ==================================================
