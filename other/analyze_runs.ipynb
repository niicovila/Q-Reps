# %%
import pandas as pd

# %% [markdown]
# ## Analyze hyperparameter tune runs

# %%
runs = pd.read_csv('/Users/nicolasvila/workplace/uni/tfg_v2/tests/tune_results_random.csv')
top_runs = runs.nlargest(22, 'reward')
top_runs.drop(['timestamp', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/num_iterations',
                        'config/num_steps',
                        'config/tau'
                        ], axis=1, inplace=True)

top_runs.reset_index(drop=True, inplace=True)
top_runs.head(22)
# Out:
#     Unnamed: 0      reward  trial_id  config/num_envs
# 0          257  500.000000  4fbdbdc9                4  \
# 1          167  453.399994  0d01c630                4
# 2           40  448.000000  01444919                4
# 3          198  406.250000  e0435a6c                4
# 4          460  374.818176  e5f6f4bf                4
# 5          373  274.875000  5a234616                4
# 6          495  241.699997  31db9fba                4
# 7          473  216.235291  3a909bff                4
# 8          287  214.500000  c6ead693                4
# 9          333  193.000000  e92ca78b                4
# 10         484  187.090912  b6c34bd0                4
# 11         435  180.399994  70129922                4
# 12         353  174.500000  ba755446                4
# 13         111  113.555557  116c8f43                4
# 14         235  112.947365  3d42510c                4
# 15         233  106.947365  28ec0d2c                4
# ...

# %% [markdown]
# ## Compute reward average accross seeds

# %%
averages = runs.groupby(runs.index // 4).agg({'reward': 'mean', **{col: 'first' for col in runs.columns if col != 'reward'}}).reset_index(drop=True)
averages = averages.sort_values(by='reward', ascending=False)
averages.reset_index(drop=True, inplace=True)
averages.drop(['config/total_timesteps',
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'config/env_id',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/total_timesteps',
                        'config/gamma',
                        'config/q_histogram',
                        'config/num_iterations',
                        'config/num_steps',
                        'config/tau'
                        ], axis=1, inplace=True)

averages.reset_index(drop=True, inplace=True)
averages.head()
# result_df.to_csv('CartPole_qreps_v2-1-averaging.csv', index=False)
# Out:
#        reward  Unnamed: 0   timestamp  config/num_envs
# 0  139.576699         256  1714610198                4  \
# 1  137.400545         164  1714605194                4
# 2  129.447463          40  1714603345                4
# 3  127.435646         460  1714636086                4
# 4   95.865802         372  1714633187                4
#
#    config/total_iterations  config/num_minibatches  config/update_epochs
# 0                     2048                      16                    50  \
# 1                     2048                      16                    50
# 2                     2048                      16                    50
# 3                     2048                      16                    50
# 4                     2048                      16                    50
#
#    config/alpha  config/eta  config/beta  ...  config/sampler_optimizer
# 0            12         NaN      0.00300  ...                      Adam  \
# ...

# %%
len(averages)
# Out:
# 128
