# %%
import pandas as pd

# %%
lunal_lander = pd.read_csv('/Users/nicolasvila/workplace/uni/tfg_v2/LunarLander_qreps_analysis_v2.csv')
lunal_lander['reward'] = lunal_lander['reward'].apply(lambda x: float(x[1:-1]))
lunal_lander = lunal_lander[lunal_lander['reward'] != 1111.0]

top_10_rewards_ll = lunal_lander.nlargest(100, 'reward')
top_10_rewards_ll.drop(['timestamp', 
                        'trial_id', 
                        'checkpoint_dir_name', 
                        'done',
                        'training_iteration',
                        'date',
                        'time_this_iter_s',
                        'time_total_s',
                        'pid',
                        'hostname',
                        'node_ip',
                        'time_since_restore',
                        'iterations_since_restore',
                        'experiment_tag',
                        'config/total_timesteps',
                        'config/env_id',
                        'config/total_timesteps',
                        'config/exp_name',
                        'config/seed',
                        'config/torch_deterministic',
                        'config/cuda',
                        'config/track',
                        'config/wandb_project_name',
                        'config/wandb_entity',
                        'config/capture_video',
                        'config/__trial_index__',
                        'config/__trial_index__',
                        ], axis=1, inplace=True)

top_10_rewards_ll.reset_index(drop=True, inplace=True)

# %%
top_10_rewards_ll.head(50)
# Out:
#         reward  config/num_envs  config/num_steps  config/anneal_lr  \
# 0   277.183600                4               256              True
# 1   272.411500                8               128              True
# 2   265.615970                4               128             False
# 3   265.615970                4               128             False
# 4   254.914430                4               128              True
# 5   254.914430                4               128              True
# 6   239.281750                4               128              True
# 7   200.151260                4               256             False
# 8   195.369110                4               128             False
# 9    77.694470                8               500              True
# 10   50.857010                8               128              True
# 11   38.394485                8               256              True
# 12   37.077300                4               256             False
# 13   33.996780                4               256              True
# 14   33.349090                4               500              True
# 15   29.391066                4               128             False
# 16   27.625496                4               500             False
# 17   25.987793                4               256             False
# 18   21.831520                4               256              True
# 19   18.954163                8               256             False
# 20   16.513290                4               128              True
# 21   15.961090                4               256             False
# 22   13.175766                4               256             False
# 23    9.698158                4               128              True
# 24    7.405655                8               128              True
# 25    6.930923                8               128              True
# 26    6.873177                4               256              True
# 27    3.382080                8               256              True
# 28    2.451065                8               128             False
# 29    0.743492                8               256             False
# 30   -0.286797                8               128              True
# 31   -0.397194                4               128             False
# 32   -1.001770                4               256              True
# 33   -1.091408                4               500              True
# 34   -2.026421                4               128             False
# 35   -2.645416                4               256             False
# 36   -4.287544                4               128              True
# 37   -5.385414                8               500             False
# 38   -6.159836                4               500              True
# 39   -6.837944                4               128              True
# 40   -7.469437                4               256              True
# 41   -9.358009                8               256             False
# 42   -9.619484                4               256              True
# 43  -10.875015                4               500             False
# 44  -11.535120                4               128             False
# 45  -11.789803                8               128             False
# 46  -14.110947                8               256             False
# 47  -14.871796                8               128              True
# 48  -15.402214                4               500              True
# 49  -16.309097                8               128              True
#
#     config/gamma  config/num_minibatches  config/policy_lr_start  \
# 0           0.99                       8                 0.00025
# 1           0.99                      16                 0.00250
# 2           0.99                       8                 0.00025
# 3           0.99                       8                 0.00025
# 4           0.99                       8                 0.00025
# 5           0.99                       8                 0.00025
# 6           0.99                       8                 0.00100
# 7           0.99                       8                 0.00100
# 8           0.99                       8                 0.00250
# 9           0.99                      16                 0.00025
# 10          0.99                      16                 0.00250
# 11          0.99                      16                 0.00100
# 12          0.99                       2                 0.00025
# 13          0.99                       4                 0.00025
# 14          0.99                       8                 0.00025
# 15          0.99                      16                 0.00250
# 16          0.99                       4                 0.00250
# 17          0.99                       8                 0.00025
# 18          0.99                       8                 0.00025
# 19          0.99                      16                 0.00025
# 20          0.99                       8                 0.00025
# 21          0.99                       8                 0.00025
# 22          0.99                       8                 0.00250
# 23          0.99                       8                 0.00025
# 24          0.99                       2                 0.00025
# 25          0.99                      16                 0.00250
# 26          0.99                       2                 0.00025
# 27          0.99                       8                 0.00025
# 28          0.99                       8                 0.00025
# 29          0.99                      16                 0.00250
# 30          0.99                      16                 0.00025
# 31          0.99                       8                 0.00025
# 32          0.99                       8                 0.00250
# 33          0.99                       2                 0.00025
# 34          0.99                       2                 0.00100
# 35          0.99                      16                 0.00025
# 36          0.99                       8                 0.00025
# 37          0.99                      16                 0.00100
# 38          0.99                       4                 0.00025
# 39          0.99                       8                 0.00250
# 40          0.99                       2                 0.00025
# 41          0.99                      16                 0.00100
# 42          0.99                       8                 0.00025
# 43          0.99                       8                 0.00250
# 44          0.99                       4                 0.00025
# 45          0.99                      16                 0.00025
# 46          0.99                       2                 0.00025
# 47          0.99                      16                 0.00025
# 48          0.99                      16                 0.00025
# 49          0.99                       4                 0.00250
#
#     config/q_lr_start  config/alpha  config/eta  config/update_epochs  \
# 0             0.00100           6.0         NaN                   100
# 1             0.00025           4.0         NaN                    50
# 2             0.00100           6.0         NaN                    50
# 3             0.00100           6.0         NaN                    50
# 4             0.00250           6.0         NaN                    50
# 5             0.00250           6.0         NaN                    50
# 6             0.00250           6.0         NaN                    50
# 7             0.00250           8.0         NaN                    50
# 8             0.00250           6.0         NaN                    50
# 9             0.00100           6.0         NaN                    50
# 10            0.00025           4.0         NaN                   100
# 11            0.10000           6.0         NaN                    50
# 12            0.00100           8.0         NaN                    50
# 13            0.00100           6.0         NaN                   100
# 14            0.00100           6.0         NaN                   100
# 15            0.00250           6.0         NaN                    10
# 16            0.00250           6.0         NaN                   100
# 17            0.00250           6.0         NaN                    50
# 18            0.00250           6.0         NaN                    50
# 19            0.00025           4.0         NaN                   300
# 20            0.00025           6.0         NaN                    50
# 21            0.00100           6.0         NaN                   100
# 22            0.00100           4.0         NaN                    50
# 23            0.00025           2.0         NaN                   300
# 24            0.00100           6.0         NaN                   100
# 25            0.00100           8.0         NaN                    50
# 26            0.00100           6.0         NaN                   100
# 27            0.00025           4.0         NaN                   300
# 28            0.00100           8.0         NaN                    50
# 29            0.00025           4.0         NaN                   300
# 30            0.00100           6.0         NaN                   100
# 31            0.00025           6.0         NaN                    50
# 32            0.00100           8.0         NaN                    10
# 33            0.00250           4.0         NaN                    50
# 34            0.00100           8.0         NaN                   100
# 35            0.00100           4.0         NaN                    50
# 36            0.00100           6.0         NaN                   100
# 37            0.00250           4.0         NaN                    10
# 38            0.00250           4.0         NaN                   100
# 39            0.00250           4.0         NaN                    50
# 40            0.00250           8.0         NaN                   100
# 41            0.00025           8.0         NaN                    10
# 42            0.00250           6.0         NaN                    10
# 43            0.00100           4.0         NaN                   100
# 44            0.00025           4.0         NaN                   100
# 45            0.00025           6.0         NaN                    50
# 46            0.00025           4.0         NaN                   300
# 47            0.00025           8.0         NaN                    50
# 48            0.10000           6.0         NaN                    50
# 49            0.00100           6.0         NaN                   100
#
#     config/autotune  config/target_entropy_scale  \
# 0             False                         0.89
# 1             False                         0.50
# 2             False                         0.89
# 3             False                         0.50
# 4             False                         0.89
# 5             False                         0.70
# 6             False                         0.89
# 7             False                         0.70
# 8             False                         0.70
# 9              True                         0.70
# 10            False                         0.50
# 11             True                         0.30
# 12            False                         0.30
# 13            False                         0.89
# 14            False                         0.89
# 15            False                         0.89
# 16            False                         0.70
# 17            False                         0.30
# 18            False                         0.89
# 19             True                         0.70
# 20            False                         0.70
# 21            False                         0.89
# 22            False                         0.70
# 23            False                         0.30
# 24            False                         0.30
# 25            False                         0.89
# 26            False                         0.89
# 27            False                         0.50
# 28             True                         0.30
# 29             True                         0.70
# 30            False                         0.30
# 31            False                         0.89
# 32            False                         0.30
# 33            False                         0.89
# 34            False                         0.70
# 35             True                         0.50
# 36            False                         0.30
# 37            False                         0.70
# 38            False                         0.30
# 39             True                         0.89
# 40            False                         0.30
# 41            False                         0.30
# 42            False                         0.70
# 43            False                         0.89
# 44            False                         0.89
# 45             True                         0.89
# 46             True                         0.89
# 47            False                         0.50
# 48            False                         0.89
# 49            False                         0.70
#
#     config/saddle_point_optimization  config/use_kl_loss  config/q_histogram  \
# 0                              False                True               False
# 1                              False                True               False
# 2                              False               False               False
# 3                              False               False               False
# 4                              False                True               False
# 5                              False                True               False
# 6                              False                True               False
# 7                              False                True               False
# 8                              False                True               False
# 9                              False                True               False
# 10                             False                True               False
# 11                             False               False               False
# 12                             False                True               False
# 13                             False                True               False
# 14                             False                True               False
# 15                             False                True               False
# 16                             False                True               False
# 17                             False                True               False
# 18                             False                True               False
# 19                             False                True               False
# 20                             False                True               False
# 21                             False                True               False
# 22                             False               False               False
# 23                             False                True               False
# 24                             False                True               False
# 25                             False                True               False
# 26                             False                True               False
# 27                             False                True               False
# 28                             False               False               False
# 29                             False               False               False
# 30                             False                True               False
# 31                             False                True               False
# 32                             False                True               False
# 33                             False                True               False
# 34                             False                True               False
# 35                             False                True               False
# 36                             False                True               False
# 37                             False                True               False
# 38                             False                True               False
# 39                             False               False               False
# 40                             False                True               False
# 41                             False                True               False
# 42                             False                True               False
# 43                             False                True               False
# 44                             False                True               False
# 45                             False                True               False
# 46                             False                True               False
# 47                             False                True               False
# 48                             False                True               False
# 49                             False                True               False
#
#     config/batch_size  config/minibatch_size  config/num_iterations
# 0                   0                      0                      0
# 1                   0                      0                      0
# 2                   0                      0                      0
# 3                   0                      0                      0
# 4                   0                      0                      0
# 5                   0                      0                      0
# 6                   0                      0                      0
# 7                   0                      0                      0
# 8                   0                      0                      0
# 9                   0                      0                      0
# 10                  0                      0                      0
# 11                  0                      0                      0
# 12                  0                      0                      0
# 13                  0                      0                      0
# 14                  0                      0                      0
# 15                  0                      0                      0
# 16                  0                      0                      0
# 17                  0                      0                      0
# 18                  0                      0                      0
# 19                  0                      0                      0
# 20                  0                      0                      0
# 21                  0                      0                      0
# 22                  0                      0                      0
# 23                  0                      0                      0
# 24                  0                      0                      0
# 25                  0                      0                      0
# 26                  0                      0                      0
# 27                  0                      0                      0
# 28                  0                      0                      0
# 29                  0                      0                      0
# 30                  0                      0                      0
# 31                  0                      0                      0
# 32                  0                      0                      0
# 33                  0                      0                      0
# 34                  0                      0                      0
# 35                  0                      0                      0
# 36                  0                      0                      0
# 37                  0                      0                      0
# 38                  0                      0                      0
# 39                  0                      0                      0
# 40                  0                      0                      0
# 41                  0                      0                      0
# 42                  0                      0                      0
# 43                  0                      0                      0
# 44                  0                      0                      0
# 45                  0                      0                      0
# 46                  0                      0                      0
# 47                  0                      0                      0
# 48                  0                      0                      0
# 49                  0                      0                      0

# %%
top_10_rewards_cp.head(13)
# Out:
#    reward  config/update_epochs  config/update_policy_epochs
# 0   500.0                   100                          300  \
# 1   500.0                   100                          300
# 2   500.0                   100                          300
# 3   500.0                   100                          300
# 4   500.0                   100                          300
# 5   500.0                   100                          300
# 6   500.0                   100                          300
# 7   500.0                   100                          300
# 8   500.0                   100                          300
# 9   500.0                   100                          450
#
#    config/num_rollouts  config/num_envs  config/gamma  config/policy_lr_start
# 0                    5                1          0.99                    0.02  \
# 1                    5                1          0.99                    0.02
# 2                    5                1          0.99                    0.02
# 3                    5                1          0.99                    0.02
# 4                    5                1          0.99                    0.02
# 5                    5                1          0.99                    0.02
# 6                    5                1          0.99                    0.02
# 7                    5                1          0.99                    0.02
# 8                    5                1          0.99                    0.02
# 9                    5                1          0.99                    0.02
#
#    config/q_lr_start  config/q_lr_end  config/policy_lr_end  config/alpha
# 0             0.0025          0.00020               0.00100           4.0  \
# 1             0.0025          0.00001               0.00001           4.0
# 2             0.0025          0.00100               0.00001           4.0
# 3             0.0025          0.00100               0.00100           4.0
# 4             0.0025          0.00020               0.00001           4.0
# 5             0.0025          0.00001               0.00020           4.0
# 6             0.0025          0.00100               0.00020           4.0
# 7             0.0025          0.00020               0.00020           4.0
# 8             0.0025          0.00020               0.00020           4.0
# 9             0.0200          0.00001               0.00020           4.0
#
#    config/eta  config/beta  config/autotune  config/target_entropy_scale
# 0         NaN      0.00004             True                         0.20  \
# 1         NaN      0.00004             True                         0.20
# 2         NaN      0.00004             True                         0.20
# 3         NaN      0.00004             True                         0.20
# 4         NaN      0.00004             True                         0.20
# 5         NaN      0.00004             True                         0.20
# 6         NaN      0.00004             True                         0.20
# 7         NaN      0.00004             True                         0.20
# 8         NaN      0.00004             True                         0.20
# 9         NaN      0.00200             True                         0.35
#
#    config/use_linear_schedule  config/saddle_point_optimization
# 0                       False                              True  \
# 1                       False                              True
# 2                       False                              True
# 3                       False                              True
# 4                       False                              True
# 5                       False                              True
# 6                       False                              True
# 7                       False                              True
# 8                       False                              True
# 9                        True                             False
#
#    config/use_kl_loss
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False

# %%
import pandas as pd

# Assuming you have two dataframes: top_10_rewards_cp and top_10_rewards_ll

# Function to find similar configurations
def find_similar_configurations(df1, df2):
    similar_configurations = []

    for idx1, row1 in df1.iterrows():
        for idx2, row2 in df2.iterrows():
            similarity_score = sum(row1[:-1] == row2[:-1])
            if similarity_score > 0:
                similar_configurations.append((idx1, idx2, similarity_score))

    return similar_configurations

# Find similar configurations
similar_configurations = find_similar_configurations(top_10_rewards_cp, top_10_rewards_ll)
similar_configurations.sort(key=lambda x: x[2], reverse=True)
# Print the top similar configurations
for config in similar_configurations[:10]:
    idx1, idx2, similarity_score = config
    print("Similarity Score:", similarity_score)
    print("Configuration CP (Index {}):".format(idx1))
    print(top_10_rewards_cp.iloc[idx1])
    print("Configuration LL (Index {}):".format(idx2))
    print(top_10_rewards_ll.iloc[idx2])
    print("="*50)
# Out:
# Similarity Score: 10
# Configuration CP (Index 3):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 3, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 10
# Configuration CP (Index 9):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                           0.002
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 9, dtype: object
# Configuration LL (Index 2):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                              0.002
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 2, dtype: object
# ==================================================
# Similarity Score: 10
# Configuration CP (Index 11):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                            0.01
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 11, dtype: object
# Configuration LL (Index 1):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                               0.01
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 1, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 0):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                      0.0002
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 0, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 0):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                      0.0002
# config/policy_lr_end                  0.001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 0, dtype: object
# Configuration LL (Index 5):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                         0.0002
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 5, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 1):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                     0.00001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 1, dtype: object
# Configuration LL (Index 6):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                   0.00001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 6, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 2):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 2, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 2):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                0.00001
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 2, dtype: object
# Configuration LL (Index 11):
# reward                              195.121782
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                          0.001
# config/policy_lr_end                   0.00001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                           True
# config/target_entropy_scale                0.5
# config/use_linear_schedule               False
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 11, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 6):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             300
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                    0.0025
# config/q_lr_end                       0.001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                         0.00004
# config/autotune                        True
# config/target_entropy_scale             0.2
# config/use_linear_schedule            False
# config/saddle_point_optimization       True
# config/use_kl_loss                    False
# Name: 6, dtype: object
# Configuration LL (Index 0):
# reward                              273.986155
# config/update_epochs                        50
# config/update_policy_epochs                300
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                    0.02
# config/q_lr_start                         0.02
# config/q_lr_end                          0.001
# config/policy_lr_end                     0.001
# config/alpha                               2.0
# config/eta                                 NaN
# config/beta                            0.00004
# config/autotune                          False
# config/target_entropy_scale                0.2
# config/use_linear_schedule                True
# config/saddle_point_optimization          True
# config/use_kl_loss                       False
# Name: 0, dtype: object
# ==================================================
# Similarity Score: 9
# Configuration CP (Index 9):
# reward                                500.0
# config/update_epochs                    100
# config/update_policy_epochs             450
# config/num_rollouts                       5
# config/num_envs                           1
# config/gamma                           0.99
# config/policy_lr_start                 0.02
# config/q_lr_start                      0.02
# config/q_lr_end                     0.00001
# config/policy_lr_end                 0.0002
# config/alpha                            4.0
# config/eta                              NaN
# config/beta                           0.002
# config/autotune                        True
# config/target_entropy_scale            0.35
# config/use_linear_schedule             True
# config/saddle_point_optimization      False
# config/use_kl_loss                    False
# Name: 9, dtype: object
# Configuration LL (Index 1):
# reward                              230.447399
# config/update_epochs                        50
# config/update_policy_epochs                 50
# config/num_rollouts                          5
# config/num_envs                              1
# config/gamma                              0.99
# config/policy_lr_start                  0.0025
# config/q_lr_start                          0.1
# config/q_lr_end                        0.00001
# config/policy_lr_end                     0.001
# config/alpha                               4.0
# config/eta                                 NaN
# config/beta                               0.01
# config/autotune                           True
# config/target_entropy_scale               0.35
# config/use_linear_schedule                True
# config/saddle_point_optimization         False
# config/use_kl_loss                        True
# Name: 1, dtype: object
# ==================================================
